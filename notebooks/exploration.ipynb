# %%
import pandas as pd

# %%
df = pd.read_json("../data/processed/combined_output.json")

# %%
df.shape
# Out:
# (27955, 12)

# %%
unique_slugs = df["slug"].unique()
sorted(unique_slugs)
# Out:
# ['rates--population--2020-decennial-pop',
#  'rates--population--2020-decennial-pop-pct',
#  'rates--population--2022-acs-pop',
#  'rates--population--2022-acs-pop-pct',
#  'rates--rates--16-for-2022',
#  'rates--rates--arrest-rate',
#  'rates--rates--arrest-rate-arrests-stops-x-100',
#  'rates--rates--citation-rate',
#  'rates--rates--citation-rate-citations-stops-x-100',
#  'rates--rates--contraband-hit-rate',
#  'rates--rates--contraband-hit-rate-searches-with-contraband-found-total-searches-x-100',
#  'rates--rates--hispanic-residents-are-double-counted-in-the-race-percentages-above',
#  'rates--rates--search-rate',
#  'rates--rates--search-rate-searches-stops-x-100',
#  'rates--rates--stop-rate',
#  'rates--rates--stop-rate-residents',
#  'rates--rates--stop-rate-residents-only-stops-of-residents-population-x-100',
#  'rates--rates--stop-rate-stops-population-x-100',
#  'rates--totals--all-stops',
#  'rates--totals--arrests',
#  'rates--totals--citations',
# ...

# %% [markdown]
# # Some random checks / scratchpad

# %%
slug_filtered_df = df[
    (df["slug"] == "stops--stop-outcome--warning") &
    (df["department"] == "St James Police Dept")
]

# %%
dept_filtered_df = df[
    (df["department"] == "St James Police Dept")
]

# %%
dept_filtered_df
# Out:
#                          key    Total    White    Black  Hispanic  \
# 23565          2022 ACS pop.  2989.00  2781.00     3.00     64.00
# 23566        2022 ACS pop. %   100.00    93.04     0.10      2.14
# 23567    2020 Decennial pop.  2930.00  2625.00    14.00     73.00
# 23568  2020 Decennial pop. %   100.00    89.59     0.48      2.49
# 23569              All stops  1740.00  1585.00    87.00     40.00
# 23570         Resident stops   477.00   457.00    10.00     10.00
# 23571               Searches   112.00   106.00     2.00      3.00
# 23572             Contraband    30.00    28.00     1.00      1.00
# 23573                Arrests    69.00    64.00     2.00      3.00
# 23574              Citations   114.00   104.00     9.00      1.00
# 23575              Stop rate    58.21    56.99  2900.00     62.50
# 23576   Stop rate, residents    15.96    16.43   333.33     15.63
# 23577            Search rate     6.44     6.69     2.30      7.50
# ...
